# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Specify the file path
file_path = r'C:\Users\Utente\Desktop\DHANA\1.xlsx'

# Read the data from Excel file
data = pd.read_excel(file_path)

# Assuming future usage likelihood is in column 21 and perception is in column 9
future_usage_col = 20  # Adjusted for zero-based indexing
perception_col = 8  # Adjusted for zero-based indexing
future_usage = data.iloc[:, future_usage_col]
perception = data.iloc[:, perception_col]

# Mapping future usage likelihood values to corresponding labels
future_usage_mapping = {
    1: 'Very likely',
    2: 'Somewhat likely',
    3: 'Neutral',
    4: 'Somewhat unlikely',
    5: 'Very unlikely'
}
future_usage_labels = future_usage.map(future_usage_mapping)

# Mapping perception values to categories: 'Complementary', 'Replacement', 'Neutral'
perception_mapping = {
    1: 'Complementary',
    2: 'Replacement',
    3: 'Neutral'
}
perception_labels = perception.map(perception_mapping)

# Create a DataFrame for the plot
df = pd.DataFrame({'Future Usage Likelihood': future_usage_labels, 'Perception': perception_labels})

# Set the plot style and size
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Create a grouped bar plot with adjusted bar width
sns.countplot(x='Perception', hue='Future Usage Likelihood', data=df, palette='Set2', order=['Complementary', 'Replacement', 'Neutral'],
              dodge=True, **{'width':0.5})  # Adjust the width of bars here (0.7 for closer bars)

# Customize the plot
plt.title('Perception of VR Yoga and Future Usage Likelihood')
plt.xlabel('Perception')
plt.ylabel('Number of participants')

# Add legend
plt.legend(title='Future Usage Likelihood', loc='upper right', bbox_to_anchor=(1.25, 1))

# Save the plot to a file (optional)
plt.savefig('perception_future_usage_grouped_bar_plot.png')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17868\940485075.py in <module>
#      41
#      42 # Create a grouped bar plot with adjusted bar width
# ---> 43 sns.countplot(x='Perception', hue='Future Usage Likelihood', data=df, palette='Set2', order=['Complementary', 'Replacement', 'Neutral'],
#      44               dodge=True, **{'width':0.5})  # Adjust the width of bars here (0.7 for closer bars)
#      45
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Specify the file path
file_path = r'C:\Users\Utente\Desktop\DHANA\1.xlsx'

# Read the data from Excel file
data = pd.read_excel(file_path)

# Assuming question 9 corresponds to VR enhancing focus and question 14 corresponds to recommendations
focus_enhancement_col = 9
recommendations_col = 14

focus_enhancement = data.iloc[:, focus_enhancement_col]
recommendations = data.iloc[:, recommendations_col]

# Mapping focus enhancement values to corresponding labels
focus_enhancement_mapping = {
    1: 'Yes, VR helps me focus better',
    2: 'No, I prefer traditional methods for focus',
    3: "I'm unsure about the impact on focus"
}
focus_enhancement_labels = focus_enhancement.map(focus_enhancement_mapping)

# Mapping recommendation values to corresponding labels
recommendations_mapping = {
    1: 'Enhance the graphics and visual quality',
    2: 'Offer more diverse and realistic environments',
    3: 'Improve motion tracking and responsiveness',
    4: 'Introduce VR yoga experiences for specific health conditions',
    5: 'Other',
    6: 'Very unlikely, I do not think they would be interested'
}
recommendations_labels = recommendations.map(recommendations_mapping)

# Create a DataFrame for the plot
df = pd.DataFrame({'Focus Enhancement': focus_enhancement_labels, 'Recommendations': recommendations_labels})

# Set the plot style and size, and adjust the bar width
sns.set(style="white", context="paper", font_scale=1.2, rc={"axes.titlesize": 12, "axes.labelsize": 10, "xtick.labelsize": 8, "ytick.labelsize": 8})
plt.figure(figsize=(8, 6))
bar_width = 0.5  # You can adjust this value to make the bars slimmer or wider

# Create the bar plot for focus enhancement (question 9) with a legend
sns.countplot(x='Focus Enhancement', data=df, palette='Set2', hue='Focus Enhancement', dodge=False)
plt.title('Focus Enhancement Using VR for Yoga')
plt.xlabel('Focus Enhancement Responses')
plt.ylabel('Number of participants')

# ... (rest of your code remains unchanged)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Specify the file path
file_path = r'C:\Users\Utente\Desktop\DHANA\1.xlsx'

# Read the data from Excel file
data = pd.read_excel(file_path)

# Assuming question 9 corresponds to VR enhancing focus and question 14 corresponds to recommendations
focus_enhancement_col = 9
recommendations_col = 14

focus_enhancement = data.iloc[:, focus_enhancement_col]
recommendations = data.iloc[:, recommendations_col]

# Mapping focus enhancement values to corresponding labels
focus_enhancement_mapping = {
    1: 'Yes, VR helps me focus better',
    2: 'No, I prefer traditional methods for focus',
    3: "I'm unsure about the impact on focus"
}
focus_enhancement_labels = focus_enhancement.map(focus_enhancement_mapping)

# Mapping recommendation values to corresponding labels
recommendations_mapping = {
    1: 'Enhance the graphics and visual quality',
    2: 'Offer more diverse and realistic environments',
    3: 'Improve motion tracking and responsiveness',
    4: 'Introduce VR yoga experiences for specific health conditions',
    5: 'Other',
    6: 'Very unlikely, I do not think they would be interested'
}
recommendations_labels = recommendations.map(recommendations_mapping)

# Create a DataFrame for the plot
df = pd.DataFrame({'Focus Enhancement': focus_enhancement_labels, 'Recommendations': recommendations_labels})

# Set the plot style and size
sns.set(style="white")
plt.figure(figsize=(12, 6))

# Create the bar plot for focus enhancement (question 9) with a legend
sns.countplot(x='Focus Enhancement', data=df, palette='Set2', hue='Focus Enhancement', dodge=False)
plt.title('Focus Enhancement Using VR for Yoga')
plt.xlabel('Focus Enhancement Responses')
plt.ylabel('Number of participants')

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Focus Enhancement'])
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(f'{height/total:.1%}', (p.get_x() + p.get_width() / 2, height),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 10),
                       textcoords='offset points')

# Create the count plot for recommendations (question 14) with a legend
plt.figure(figsize=(12, 6))
sns.countplot(y='Recommendations', data=df, palette='Set2', hue='Recommendations', dodge=False)
plt.title('Recommendations for Improving VR Yoga')
plt.xlabel('Number of participants')
plt.ylabel('Recommendations')

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Recommendations'])
for p in plt.gca().patches:
    width = p.get_width()
    plt.gca().annotate(f'{width/total:.1%}', (width, p.get_y() + p.get_height() / 2),
                       ha='center', va='center', fontsize=10, color='black', xytext=(-20, 0),
                       textcoords='offset points')

# Add legends for both plots
plt.legend(title='Focus Enhancement', loc='upper right', bbox_to_anchor=(1.25, 1))
plt.legend(title='Recommendations', loc='upper right', bbox_to_anchor=(1.25, 1))

# Save the plot to a file (optional)
plt.savefig('focus_enhancement_recommendations_combined_plot_with_legends.png')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ... (your code for reading data and processing labels remains unchanged) ...

# Set the plot style and size
sns.set(style="white")
plt.figure(figsize=(12, 6))

# Create the bar plot for focus enhancement (question 9) with a legend and adjust bar width
sns.countplot(x='Focus Enhancement', data=df, palette='Set2', hue='Focus Enhancement', dodge=False, linewidth=0.9, alpha=0.7, saturation=1, width=0.6)
plt.title('Focus Enhancement Using VR for Yoga')
plt.xlabel('Focus Enhancement Responses')
plt.ylabel('Number of participants')

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Focus Enhancement'])
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(f'{height/total:.1%}', (p.get_x() + p.get_width() / 2, height),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 10),
                       textcoords='offset points')

# Create the count plot for recommendations (question 14) with a legend and adjust bar width
plt.figure(figsize=(12, 6))
sns.countplot(y='Recommendations', data=df, palette='Set2', hue='Recommendations', dodge=False, linewidth=0.3, alpha=0.7, saturation=1, width=0.2)
plt.title('Recommendations for Improving VR Yoga')
plt.xlabel('Number of participants')
plt.ylabel('Recommendations')

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Recommendations'])
for p in plt.gca().patches:
    width = p.get_width()
    plt.gca().annotate(f'{width/total:.1%}', (width, p.get_y() + p.get_height() / 2),
                       ha='center', va='center', fontsize=10, color='black', xytext=(-20, 0),
                       textcoords='offset points')

# Add legends for both plots
plt.legend(title='Focus Enhancement', loc='upper right', bbox_to_anchor=(1.25, 1))
plt.legend(title='Recommendations', loc='upper right', bbox_to_anchor=(1.25, 1))

# Save the plot to a file (optional)
plt.savefig('focus_enhancement_recommendations_combined_plot_with_legends_slim_bars.png')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17868\1045576188.py in <module>
#      10
#      11 # Create the bar plot for focus enhancement (question 9) with a legend and adjust bar width
# ---> 12 sns.countplot(x='Focus Enhancement', data=df, palette='Set2', hue='Focus Enhancement', dodge=False, linewidth=0.9, alpha=0.7, saturation=1, width=0.6)
#      13 plt.title('Focus Enhancement Using VR for Yoga')
#      14 plt.xlabel('Focus Enhancement Responses')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Specify the file path
file_path = r'C:\Users\Utente\Desktop\DHANA\1.xlsx'

# Read the data from Excel file
data = pd.read_excel(file_path)

# Assuming question 9 corresponds to VR enhancing focus and question 14 corresponds to recommendations
focus_enhancement_col = 9
recommendations_col = 14

focus_enhancement = data.iloc[:, focus_enhancement_col]
recommendations = data.iloc[:, recommendations_col]

# Mapping focus enhancement values to corresponding labels
focus_enhancement_mapping = {
    1: 'Yes, VR helps me focus better',
    2: 'No, I prefer traditional methods for focus',
    3: "I'm unsure about the impact on focus"
}
focus_enhancement_labels = focus_enhancement.map(focus_enhancement_mapping)

# Mapping recommendation values to corresponding labels
recommendations_mapping = {
    1: 'Enhance the graphics and visual quality',
    2: 'Offer more diverse and realistic environments',
    3: 'Improve motion tracking and responsiveness',
    4: 'Introduce VR yoga experiences for specific health conditions',
    5: 'Other',
    6: 'Very unlikely, I do not think they would be interested'
}
recommendations_labels = recommendations.map(recommendations_mapping)

# Create a DataFrame for the plot
df = pd.DataFrame({'Focus Enhancement': focus_enhancement_labels, 'Recommendations': recommendations_labels})

# Set the plot style and size
sns.set(style="white")
plt.figure(figsize=(12, 6))

# Create the bar plot for focus enhancement (question 9) with a legend and adjust linewidth
sns.countplot(x='Focus Enhancement', data=df, palette='Set2', hue='Focus Enhancement', dodge=False, linewidth=0.2)
plt.title('Focus Enhancement Using VR for Yoga')
plt.xlabel('Focus Enhancement Responses')
plt.ylabel('Number of participants')

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Focus Enhancement'])
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(f'{height/total:.1%}', (p.get_x() + p.get_width() / 2, height),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 10),
                       textcoords='offset points')

plt.figure(figsize=(12, 6))
sns.barplot(y='Recommendations', data=df, palette='Set2', ci=None, estimator=len, dodge=True, errcolor=".2", edgecolor=".2", linewidth=0.5, saturation=1, orient='h', dodge_order=None, hue='Recommendations', order=None, hue_order=None, estimator_order=None, units=None, hue_units=None, errwidth=None, capsize=None, dodge_ratio=0.1, ax=None, **kwargs)
plt.title('Recommendations for Improving VR Yoga')
plt.xlabel('Number of participants')
plt.ylabel('Recommendations')

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Recommendations'])
for p in plt.gca().patches:
    width = p.get_width()
    plt.gca().annotate(f'{width/total:.1%}', (width, p.get_y() + p.get_height() / 2),
                       ha='center', va='center', fontsize=10, color='black', xytext=(-20, 0),
                       textcoords='offset points')

# Add legends for both plots
plt.legend(title='Focus Enhancement', loc='upper right', bbox_to_anchor=(1.25, 1))
plt.legend(title='Recommendations', loc='upper right', bbox_to_anchor=(1.25, 1))

# Save the plot to a file (optional)
plt.savefig('focus_enhancement_recommendations_combined_plot_with_legends.png')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17868\2216886091.py in <module>
#      57
#      58 plt.figure(figsize=(12, 6))
# ---> 59 sns.barplot(y='Recommendations', data=df, palette='Set2', ci=None, estimator=len, dodge=True, errcolor=".2", edgecolor=".2", linewidth=0.5, saturation=1, orient='h', dodge_order=None, hue='Recommendations', order=None, hue_order=None, estimator_order=None, units=None, hue_units=None, errwidth=None, capsize=None, dodge_ratio=0.1, ax=None, **kwargs)
#      60 plt.title('Recommendations for Improving VR Yoga')
#      61 plt.xlabel('Number of participants')
#
# NameError: name 'kwargs' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Specify the file path
file_path = r'C:\Users\Utente\Desktop\DHANA\1.xlsx'

# Read the data from Excel file
data = pd.read_excel(file_path)

# Assuming Q12 corresponds to the question about using VR technology for other health and wellness aspects
# and Q10 corresponds to the question about physical discomfort or motion sickness
willingness_col = 12
discomfort_col = 10

willingness = data.iloc[:, willingness_col]
discomfort = data.iloc[:, discomfort_col]

# Mapping willingness values to corresponding labels
willingness_mapping = {
    1: 'Yes, VR can enhance wellness practices',
    2: 'No, prefer to keep VR separate',
    3: 'Not sure about VR potential in other areas'
}
willingness_labels = willingness.map(willingness_mapping)

# Mapping discomfort values to corresponding labels
discomfort_mapping = {
    1: 'Frequently',
    2: 'Occasionally',
    3: 'Rarely',
    4: 'No discomfort'
}
discomfort_labels = discomfort.map(discomfort_mapping)

# Create a DataFrame for the plot
df = pd.DataFrame({'Willingness': willingness_labels, 'Discomfort': discomfort_labels})

# Set the plot style and size
sns.set(style="white")
plt.figure(figsize=(10, 6))

# Create a grouped bar plot
sns.countplot(x='Willingness', hue='Discomfort', data=df, palette='Set2', dodge=False)

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Willingness'])
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(f'{height/total:.1%}', (p.get_x() + p.get_width() / 2, height),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 10),
                       textcoords='offset points')

# Add legend
plt.legend(title='Discomfort Level', loc='upper right', bbox_to_anchor=(1.25, 1))

# Customize the plot
plt.title('Willingness to Use VR Technology for Other Health and Wellness Aspects')
plt.xlabel('Willingness')
plt.ylabel('Number of participants')

# Save the plot to a file (optional)
plt.savefig('willingness_discomfort_grouped_bar_plot_with_percentages.png')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Specify the file path
file_path = r'C:\Users\Utente\Desktop\DHANA\1.xlsx'

# Read the data from Excel file
data = pd.read_excel(file_path)

# Assuming future usage likelihood is in question 20 and perception is in question 8
future_usage_col = 20
perception_col = 8
future_usage = data.iloc[:, future_usage_col]
perception = data.iloc[:, perception_col]

# Mapping future usage likelihood values to corresponding labels
future_usage_mapping = {
    1: 'Very likely',
    2: 'Somewhat likely',
    3: 'Neutral',
    4: 'Somewhat unlikely',
    5: 'Very unlikely'
}
future_usage_labels = future_usage.map(future_usage_mapping)

# Mapping perception values to categories: 'Complementary', 'Replacement', 'Neutral'
perception_mapping = {
    1: 'Complementary',
    2: 'Replacement',
    3: 'Neutral'
}
perception_labels = perception.map(perception_mapping)

# Create a DataFrame for the plot
df = pd.DataFrame({'Future Usage Likelihood': future_usage_labels, 'Perception': perception_labels})

# Set the plot style and size
sns.set(style="white")
plt.figure(figsize=(10, 6))

# Create a grouped bar plot
sns.countplot(x='Perception', hue='Future Usage Likelihood', data=df, palette='Set2', dodge=False)

# Calculate the percentage of participants for each category and display on the columns
total = len(df['Perception'])
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(f'{height/total:.1%}', (p.get_x() + p.get_width() / 2, height),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 10),
                       textcoords='offset points')

# Customize the plot
plt.title('Perception of VR Yoga and Future Usage Likelihood')
plt.xlabel('Perception')
plt.ylabel('Number of participents')

# Add legend
plt.legend(title='Future Usage Likelihood', loc='upper right', bbox_to_anchor=(1.25, 1))

# Save the plot to a file (optional)
plt.savefig('perception_future_usage_grouped_bar_plot_with_percentages.png')

# Show the plot
plt.show()
